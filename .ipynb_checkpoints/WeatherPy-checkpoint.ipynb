# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
max_temp = []
wind_speed = []

units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + weather_api_key + "&units=" + units + "&q=" 
#query_url

# %%
index = 0
for city in cities:
    print(f"Processing Record {index} {city}")

    # Get one of the posts
    response = requests.get(query_url + city).json()
    #print(response)

    try:
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
    except:
        print("Skipping. Value not found.")
        pass
    index += 1
    #if index == 1:
        #break
# Out:
# Processing Record 0 taolanaro
# Skipping. Value not found.
# Processing Record 1 nizhneyansk
# Skipping. Value not found.
# Processing Record 2 rikitea
# Processing Record 3 ushuaia
# Processing Record 4 pasan
# Processing Record 5 bredasdorp
# Processing Record 6 busselton
# Processing Record 7 nanortalik
# Processing Record 8 nome
# Processing Record 9 hermanus
# Processing Record 10 margate
# Processing Record 11 nsanje
# Processing Record 12 cayenne
# Processing Record 13 karkaralinsk
# Skipping. Value not found.
# Processing Record 14 luderitz
# Processing Record 15 mataura
# Processing Record 16 savannakhet
# Processing Record 17 goderich
# Processing Record 18 chardara
# Processing Record 19 airai
# Processing Record 20 hithadhoo
# Processing Record 21 husavik
# Processing Record 22 clyde river
# Processing Record 23 kapaa
# Processing Record 24 punta arenas
# Processing Record 25 upernavik
# Processing Record 26 buin
# Processing Record 27 saint-philippe
# Processing Record 28 sitka
# Processing Record 29 molina
# Processing Record 30 belushya guba
# Skipping. Value not found.
# Processing Record 31 lamar
# Processing Record 32 vaitupu
# Skipping. Value not found.
# Processing Record 33 gwadar
# Processing Record 34 southampton
# Processing Record 35 gusinoye ozero
# Processing Record 36 hasaki
# Processing Record 37 jamestown
# Processing Record 38 hobart
# Processing Record 39 atherton
# Processing Record 40 kavieng
# Processing Record 41 saleaula
# Skipping. Value not found.
# Processing Record 42 camacha
# Processing Record 43 albany
# Processing Record 44 hervey bay
# Processing Record 45 hokitika
# Processing Record 46 puerto ayora
# Processing Record 47 arraial do cabo
# Processing Record 48 new norfolk
# Processing Record 49 rio muerto
# Processing Record 50 agua prieta
# Processing Record 51 lebu
# Processing Record 52 ust-ilimsk
# Processing Record 53 cerritos
# Processing Record 54 aklavik
# Processing Record 55 muzhi
# Processing Record 56 bay point
# Processing Record 57 severo-kurilsk
# Processing Record 58 lalitpur
# Processing Record 59 saskylakh
# Processing Record 60 cidreira
# Processing Record 61 deh rawud
# Skipping. Value not found.
# Processing Record 62 hammerfest
# Processing Record 63 bima
# Processing Record 64 sibolga
# Processing Record 65 pevek
# Processing Record 66 hovd
# Processing Record 67 dingle
# Processing Record 68 ngunguru
# Processing Record 69 bolungarvik
# Skipping. Value not found.
# Processing Record 70 laguna
# Processing Record 71 madang
# Processing Record 72 cabo san lucas
# Processing Record 73 surt
# Processing Record 74 la seyne-sur-mer
# Processing Record 75 qaanaaq
# Processing Record 76 koulamoutou
# Processing Record 77 tautira
# Processing Record 78 la union
# Processing Record 79 san rafael
# Processing Record 80 caraballeda
# Processing Record 81 porto uniao
# Processing Record 82 ust-maya
# Processing Record 83 rudnyy
# Processing Record 84 doka
# Processing Record 85 yar-sale
# Processing Record 86 chuy
# Processing Record 87 grand river south east
# Skipping. Value not found.
# Processing Record 88 khatanga
# Processing Record 89 atuona
# Processing Record 90 tuktoyaktuk
# Processing Record 91 mount isa
# Processing Record 92 mahebourg
# Processing Record 93 katsuura
# Processing Record 94 dongsheng
# Processing Record 95 jiexiu
# Processing Record 96 port alfred
# Processing Record 97 cao bang
# Processing Record 98 hofn
# Processing Record 99 ust-nera
# Processing Record 100 mawlaik
# Processing Record 101 dakar
# Processing Record 102 carnarvon
# Processing Record 103 burbach
# Processing Record 104 port macquarie
# Processing Record 105 leningradskiy
# Processing Record 106 vaini
# Processing Record 107 malakisi
# Skipping. Value not found.
# Processing Record 108 kindu
# Processing Record 109 ribeira grande
# Processing Record 110 waipawa
# Processing Record 111 butaritari
# Processing Record 112 chokurdakh
# Processing Record 113 nikolskoye
# Processing Record 114 porto novo
# Processing Record 115 san patricio
# Processing Record 116 portland
# Processing Record 117 pombal
# Processing Record 118 bambous virieux
# Processing Record 119 gandzak
# Processing Record 120 esperance
# Processing Record 121 dodoma
# Processing Record 122 lavrentiya
# Processing Record 123 serafimovich
# Processing Record 124 senneterre
# Processing Record 125 port elizabeth
# Processing Record 126 sao filipe
# Processing Record 127 barrow
# Processing Record 128 riyadh
# Processing Record 129 baihar
# Processing Record 130 novo cruzeiro
# Processing Record 131 toliary
# Skipping. Value not found.
# Processing Record 132 tessalit
# Processing Record 133 bluff
# Processing Record 134 klaksvik
# Processing Record 135 fort nelson
# Processing Record 136 motygino
# Processing Record 137 vaitape
# Processing Record 138 attawapiskat
# Skipping. Value not found.
# Processing Record 139 aljezur
# Processing Record 140 constitucion
# Processing Record 141 nhamunda
# Processing Record 142 barentsburg
# Skipping. Value not found.
# Processing Record 143 trelew
# Processing Record 144 hegang
# Processing Record 145 ambilobe
# Processing Record 146 bethel
# Processing Record 147 beian
# Processing Record 148 rauma
# Processing Record 149 sao joao da barra
# Processing Record 150 dera din panah
# Skipping. Value not found.
# Processing Record 151 tasiilaq
# Processing Record 152 east london
# Processing Record 153 georgetown
# Processing Record 154 cape town
# Processing Record 155 mys shmidta
# Skipping. Value not found.
# Processing Record 156 sola
# Processing Record 157 castro
# Processing Record 158 dikson
# Processing Record 159 namatanai
# Processing Record 160 shingu
# Processing Record 161 meulaboh
# Processing Record 162 flinders
# Processing Record 163 rocha
# Processing Record 164 hambantota
# Processing Record 165 marsh harbour
# Processing Record 166 bilma
# Processing Record 167 ballina
# Processing Record 168 victoria
# Processing Record 169 amderma
# Skipping. Value not found.
# Processing Record 170 bathsheba
# Processing Record 171 yellowknife
# Processing Record 172 taos
# Processing Record 173 gawler
# Processing Record 174 mayumba
# Processing Record 175 pankrushikha
# Processing Record 176 tuatapere
# Processing Record 177 chute-aux-outardes
# Processing Record 178 narasannapeta
# Processing Record 179 thayetmyo
# Processing Record 180 port-gentil
# Processing Record 181 manavalakurichi
# Processing Record 182 zharkovskiy
# Processing Record 183 the valley
# Processing Record 184 vila do maio
# Processing Record 185 kita
# Processing Record 186 fernley
# Processing Record 187 ponta do sol
# Processing Record 188 avarua
# Processing Record 189 labuan
# Processing Record 190 daoukro
# Processing Record 191 saint-pierre
# Processing Record 192 fortuna
# Processing Record 193 bargal
# Skipping. Value not found.
# Processing Record 194 yuncheng
# Processing Record 195 abonnema
# Processing Record 196 hilo
# Processing Record 197 kracheh
# Skipping. Value not found.
# Processing Record 198 samusu
# Skipping. Value not found.
# Processing Record 199 farafangana
# Processing Record 200 norman wells
# Processing Record 201 talnakh
# Processing Record 202 altay
# Processing Record 203 nipawin
# Processing Record 204 almaznyy
# Processing Record 205 lokosovo
# Processing Record 206 souillac
# Processing Record 207 saldanha
# Processing Record 208 tchollire
# Processing Record 209 provideniya
# Processing Record 210 komsomolskiy
# Processing Record 211 sechura
# Processing Record 212 genhe
# Processing Record 213 san cristobal
# Processing Record 214 dunedin
# Processing Record 215 san lorenzo
# Processing Record 216 vegreville
# Processing Record 217 gainesville
# Processing Record 218 matay
# Processing Record 219 vao
# Processing Record 220 road town
# Processing Record 221 tasbuget
# Skipping. Value not found.
# Processing Record 222 preobrazheniye
# Processing Record 223 grand-santi
# Processing Record 224 abu samrah
# Processing Record 225 compostela
# Processing Record 226 taoudenni
# Processing Record 227 thompson
# Processing Record 228 ambodifototra
# Skipping. Value not found.
# Processing Record 229 torbay
# Processing Record 230 yenagoa
# Processing Record 231 nicolas bravo
# Processing Record 232 hobyo
# Processing Record 233 auki
# Processing Record 234 lensk
# Processing Record 235 phayao
# Processing Record 236 calderitas
# Processing Record 237 bilibino
# Processing Record 238 mar del plata
# Processing Record 239 illoqqortoormiut
# Skipping. Value not found.
# Processing Record 240 atikokan
# Processing Record 241 havelock
# Processing Record 242 geraldton
# Processing Record 243 saint george
# Processing Record 244 gornyak
# Processing Record 245 tiksi
# Processing Record 246 ilulissat
# Processing Record 247 quatre cocos
# Processing Record 248 kangaatsiaq
# Processing Record 249 alofi
# Processing Record 250 buenos aires
# Processing Record 251 rundu
# Processing Record 252 nabire
# Processing Record 253 bani walid
# Processing Record 254 aswan
# Processing Record 255 lahij
# Processing Record 256 port hardy
# Processing Record 257 isla mujeres
# Processing Record 258 mujiayingzi
# Processing Record 259 tezu
# Processing Record 260 gunjur
# Processing Record 261 moratuwa
# Processing Record 262 tsimlyansk
# Processing Record 263 hamilton
# Processing Record 264 faanui
# Processing Record 265 betera
# Processing Record 266 navalmoral de la mata
# Processing Record 267 kaz
# Processing Record 268 aguimes
# Processing Record 269 katangli
# Processing Record 270 halifax
# Processing Record 271 tabas
# Processing Record 272 diebougou
# Processing Record 273 kruisfontein
# Processing Record 274 longyearbyen
# Processing Record 275 bagdarin
# Processing Record 276 vostok
# Processing Record 277 jeremie
# Processing Record 278 isangel
# Processing Record 279 kodiak
# Processing Record 280 macau
# Processing Record 281 tabuk
# Processing Record 282 tawkar
# Skipping. Value not found.
# Processing Record 283 liverpool
# Processing Record 284 jackson
# Processing Record 285 santiago del estero
# Processing Record 286 los llanos de aridane
# Processing Record 287 kamenskoye
# Skipping. Value not found.
# Processing Record 288 shahrud
# Processing Record 289 codrington
# Processing Record 290 narsaq
# Processing Record 291 korla
# Processing Record 292 sentyabrskiy
# Skipping. Value not found.
# Processing Record 293 west bay
# Processing Record 294 svetlogorsk
# Processing Record 295 srandakan
# Processing Record 296 banjar
# Processing Record 297 north bend
# Processing Record 298 cabo rojo
# Processing Record 299 marzuq
# Processing Record 300 richards bay
# Processing Record 301 koslan
# Processing Record 302 teguldet
# Processing Record 303 tumannyy
# Skipping. Value not found.
# Processing Record 304 palencia
# Processing Record 305 dwarka
# Processing Record 306 myanaung
# Processing Record 307 tabou
# Processing Record 308 junqueiro
# Processing Record 309 la ronge
# Processing Record 310 maceio
# Processing Record 311 shu
# Processing Record 312 khash
# Processing Record 313 tadine
# Processing Record 314 oranjemund
# Processing Record 315 zhigansk
# Processing Record 316 shaowu
# Processing Record 317 bowen
# Processing Record 318 siuna
# Processing Record 319 caravelas
# Processing Record 320 olafsvik
# Processing Record 321 ibra
# Processing Record 322 fare
# Processing Record 323 honiara
# Processing Record 324 bandrele
# Processing Record 325 naze
# Processing Record 326 goundam
# Processing Record 327 kavaratti
# Processing Record 328 kenai
# Processing Record 329 solnechnyy
# Processing Record 330 galveston
# Processing Record 331 beringovskiy
# Processing Record 332 homagama
# Processing Record 333 presidencia roque saenz pena
# Processing Record 334 cuamba
# Processing Record 335 sehithwa
# Processing Record 336 umm kaddadah
# Processing Record 337 lagoa
# Processing Record 338 ahipara
# Processing Record 339 jishou
# Processing Record 340 erzin
# Processing Record 341 marsa matruh
# Processing Record 342 kudahuvadhoo
# Processing Record 343 kahului
# Processing Record 344 buchmany
# Processing Record 345 wageningen
# Processing Record 346 stornoway
# Processing Record 347 sabha
# Processing Record 348 saint-louis
# Processing Record 349 voinesti
# Processing Record 350 gizo
# Processing Record 351 burnie
# Processing Record 352 mount gambier
# Processing Record 353 bengkulu
# Processing Record 354 cody
# Processing Record 355 carmona
# Processing Record 356 aldan
# Processing Record 357 sinazongwe
# Processing Record 358 cherskiy
# Processing Record 359 yeppoon
# Processing Record 360 forest lake
# Processing Record 361 ngukurr
# Skipping. Value not found.
# Processing Record 362 fort frances
# Processing Record 363 winnemucca
# Processing Record 364 vila
# Processing Record 365 bonthe
# Processing Record 366 jinchang
# Processing Record 367 turbat
# Processing Record 368 khonuu
# Skipping. Value not found.
# Processing Record 369 kinsale
# Processing Record 370 axim
# Processing Record 371 aguililla
# Processing Record 372 oriximina
# Processing Record 373 kang
# Processing Record 374 norfolk
# Processing Record 375 cabra
# Processing Record 376 timberlake
# Processing Record 377 kenora
# Processing Record 378 changji
# Processing Record 379 svetlyy
# Processing Record 380 ola
# Processing Record 381 northam
# Processing Record 382 utiroa
# Skipping. Value not found.
# Processing Record 383 ucluelet
# Processing Record 384 bereda
# Processing Record 385 coihaique
# Processing Record 386 luganville
# Processing Record 387 mantua
# Processing Record 388 paamiut
# Processing Record 389 falkoping
# Skipping. Value not found.
# Processing Record 390 bumba
# Processing Record 391 mehamn
# Processing Record 392 noyabrsk
# Processing Record 393 andra
# Processing Record 394 makokou
# Processing Record 395 russell
# Processing Record 396 nizwa
# Processing Record 397 olinda
# Processing Record 398 mitchell
# Processing Record 399 matara
# Processing Record 400 neuquen
# Processing Record 401 hirara
# Processing Record 402 chara
# Processing Record 403 aykhal
# Processing Record 404 tsihombe
# Skipping. Value not found.
# Processing Record 405 pusad
# Processing Record 406 necochea
# Processing Record 407 beeville
# Processing Record 408 khasan
# Processing Record 409 kaeo
# Processing Record 410 yermakovskoye
# Processing Record 411 egvekinot
# Processing Record 412 guerrero negro
# Processing Record 413 aloleng
# Processing Record 414 berdigestyakh
# Processing Record 415 nagarote
# Processing Record 416 espera feliz
# Processing Record 417 parana
# Processing Record 418 broome
# Processing Record 419 marcona
# Skipping. Value not found.
# Processing Record 420 tapes
# Processing Record 421 imeni poliny osipenko
# Processing Record 422 sydney mines
# Processing Record 423 vila franca do campo
# Processing Record 424 inderborskiy
# Skipping. Value not found.
# Processing Record 425 batagay-alyta
# Processing Record 426 qaqortoq
# Processing Record 427 trapani
# Processing Record 428 fairbanks
# Processing Record 429 kadoma
# Processing Record 430 porto seguro
# Processing Record 431 lesnyye polyany
# Processing Record 432 pochutla
# Processing Record 433 itoman
# Processing Record 434 college
# Processing Record 435 tarbes
# Processing Record 436 srednekolymsk
# Processing Record 437 povenets
# Processing Record 438 varhaug
# Processing Record 439 pisco
# Processing Record 440 saryshagan
# Skipping. Value not found.
# Processing Record 441 rawson
# Processing Record 442 alta floresta
# Processing Record 443 carballo
# Processing Record 444 hoquiam
# Processing Record 445 lompoc
# Processing Record 446 krasnoselkup
# Processing Record 447 toyooka
# Processing Record 448 brigham city
# Processing Record 449 misratah
# Processing Record 450 outjo
# Processing Record 451 ambulu
# Processing Record 452 hargeysa
# Processing Record 453 grenada
# Processing Record 454 birao
# Processing Record 455 atambua
# Processing Record 456 betioky
# Processing Record 457 tazmalt
# Processing Record 458 hit
# Processing Record 459 coquimbo
# Processing Record 460 tura
# Processing Record 461 sisimiut
# Processing Record 462 najran
# Processing Record 463 kuche
# Skipping. Value not found.
# Processing Record 464 broken hill
# Processing Record 465 yantarnyy
# Processing Record 466 medak
# Processing Record 467 belyy yar
# Processing Record 468 ndende
# Processing Record 469 tilichiki
# Processing Record 470 kangasala
# Processing Record 471 dickinson
# Processing Record 472 teterow
# Processing Record 473 wanning
# Processing Record 474 beloha
# Processing Record 475 pokaran
# Processing Record 476 vertientes
# Processing Record 477 banmo
# Skipping. Value not found.
# Processing Record 478 vallenar
# Processing Record 479 yuli
# Processing Record 480 krasnoborsk
# Processing Record 481 mackay
# Processing Record 482 palabuhanratu
# Skipping. Value not found.
# Processing Record 483 ferzikovo
# Processing Record 484 dumfries
# Processing Record 485 ancud
# Processing Record 486 wamba
# Processing Record 487 belaya gora
# Processing Record 488 iisalmi
# Processing Record 489 saint anthony
# Processing Record 490 boca do acre
# Processing Record 491 umzimvubu
# Skipping. Value not found.
# Processing Record 492 nikolsk
# Processing Record 493 tres coracoes
# Processing Record 494 maningrida
# Processing Record 495 salina cruz
# Processing Record 496 jieshi
# Processing Record 497 pitimbu
# Processing Record 498 dasoguz
# Processing Record 499 koumac
# Processing Record 500 manokwari
# Processing Record 501 meadow lake
# Processing Record 502 herborn
# Processing Record 503 hami
# Processing Record 504 kisanga
# Processing Record 505 alice springs
# Processing Record 506 san quintin
# Processing Record 507 coahuayana
# Processing Record 508 mlonggo
# Processing Record 509 chumikan
# Processing Record 510 hun
# Processing Record 511 samarai
# Processing Record 512 teshie
# Processing Record 513 nikolayevskaya
# Processing Record 514 tupaciguara
# Processing Record 515 kutum
# Processing Record 516 tazovskiy
# Processing Record 517 nioro
# Processing Record 518 mushie
# Processing Record 519 filingue
# Processing Record 520 baruun-urt
# Processing Record 521 dali
# Processing Record 522 del rio
# Processing Record 523 sao gabriel da cachoeira
# Processing Record 524 faya
# Processing Record 525 paro
# Processing Record 526 praia
# Processing Record 527 meyungs
# Skipping. Value not found.
# Processing Record 528 filadelfia
# Processing Record 529 kathmandu
# Processing Record 530 jilove u prahy
# Processing Record 531 sorvag
# Skipping. Value not found.
# Processing Record 532 tidore
# Skipping. Value not found.
# Processing Record 533 gadag
# Processing Record 534 nakamura
# Processing Record 535 timizart
# Processing Record 536 ewa beach
# Processing Record 537 innisfail
# Processing Record 538 baghdad
# Processing Record 539 kosino
# Processing Record 540 sembe
# Processing Record 541 isabela
# Processing Record 542 te anau
# Processing Record 543 labytnangi
# Processing Record 544 lata
# Processing Record 545 asau
# Processing Record 546 kaitangata
# Processing Record 547 pampa
# Processing Record 548 portoferraio
# Processing Record 549 bethanien
# Processing Record 550 khandyga
# Processing Record 551 deputatskiy
# Processing Record 552 tecoanapa
# Processing Record 553 haibowan
# Skipping. Value not found.
# Processing Record 554 cairns
# Processing Record 555 valparaiso
# Processing Record 556 borogontsy
# Processing Record 557 adeje
# Processing Record 558 quesnel
# Processing Record 559 kalabo
# Processing Record 560 dalmatovo
# Processing Record 561 khormuj
# Skipping. Value not found.
# Processing Record 562 lasa
# Processing Record 563 bikapur
# Processing Record 564 tiarei
# Processing Record 565 dargaville
# Processing Record 566 davila
# Processing Record 567 poum
# Processing Record 568 pacific grove
# Processing Record 569 cangucu
# Processing Record 570 coulihaut
# Skipping. Value not found.
# Processing Record 571 phan rang
# Skipping. Value not found.
# Processing Record 572 jalu
# Processing Record 573 arequipa
# Processing Record 574 rio gallegos
# Processing Record 575 goure
# Processing Record 576 guiratinga
# Processing Record 577 mahon
# Processing Record 578 bonavista
# Processing Record 579 challapata
# Processing Record 580 crib point
# Processing Record 581 tabiauea
# Skipping. Value not found.
# Processing Record 582 xiongzhou
# Processing Record 583 touros
# Processing Record 584 falam
# Processing Record 585 pitanga
# Processing Record 586 acarau
# Processing Record 587 bedele
# Processing Record 588 watsa
# Processing Record 589 roslyakovo
# Processing Record 590 la palma
# Processing Record 591 cheremukhovo
# Processing Record 592 kholm
# Processing Record 593 iqaluit
# Processing Record 594 walvis bay
# Processing Record 595 cherdyn
# Processing Record 596 port-cartier

# %%
print(len(city_name), len(cloudiness), len(country), len(date), len(humidity), len(lat), len(lng), len(temp), len(max_temp), len(wind_speed))
# Out:
# 551 551 551 551 551 551 551 551 551 551

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Temperature": temp,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Rikitea          94      PF  1580788956        77 -23.12 -134.97
# 1         Ushuaia          75      AR  1580788956        66 -54.80  -68.30
# 2           Pasan          38      IN  1580788956        45  22.85   82.20
# 3      Bredasdorp          92      ZA  1580788956        88 -34.53   20.04
# 4       Busselton          40      AU  1580788752        19 -33.65  115.33
# ..            ...         ...     ...         ...       ...    ...     ...
# 546         Kholm         100      RU  1580789051        88  59.27   32.85
# 547       Iqaluit          90      CA  1580789052        77  63.75  -68.51
# 548    Walvis Bay          33      NA  1580789052        93 -22.96   14.51
# 549       Cherdyn         100      RU  1580789052        97  60.40   56.48
# 550  Port-Cartier           5      CA  1580789052        72  50.03  -66.87
#
#      Temperature  Max Temp  Wind Speed
# 0          78.84     78.84       11.99
# 1          51.80     51.80       16.11
# 2          58.91     58.91        5.91
# 3          73.90     75.00        5.82
# 4          86.59     90.00        9.42
# ..           ...       ...         ...
# 546        24.78     24.78       14.27
# 547         5.00      5.00        3.36
# 548        63.00     63.00        5.99
# 549        28.00     28.00        6.06
# 550        15.80     15.80        8.05
#
# [551 rows x 10 columns]

# %%
weather_data.to_csv("weatherpy.csv",index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"],
            weather_data["Temperature"],
            color="red")
plt.title("Latitude vs. Temperature" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)
plt.xlim([-100, 100])
plt.ylim([-50, 110])

plt.savefig("lat_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"],
            weather_data["Humidity"],
            color="purple")
plt.title("Latitude vs. Humidity" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)
plt.xlim([-100, 100])
plt.ylim([-5, 110])

plt.savefig("lat_humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"],
            weather_data["Cloudiness"],
            color="black")
plt.title("Latitude vs. Cloudiness" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)
plt.xlim([-100, 100])
plt.ylim([-10, 110])

plt.savefig("lat_cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"],
            weather_data["Wind Speed"],
            color="blue")
plt.title("Latitude vs. Wind Speed" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.xlim([-100, 100])
plt.ylim([-10, 60])

plt.savefig("lat_wind_speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north = weather_data.loc[(weather_data["Lat"] >= 0)]
south = weather_data.loc[(weather_data["Lat"] < 0)]
south
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Rikitea          94      PF  1580788956        77 -23.12 -134.97
# 1       Ushuaia          75      AR  1580788956        66 -54.80  -68.30
# 3    Bredasdorp          92      ZA  1580788956        88 -34.53   20.04
# 4     Busselton          40      AU  1580788752        19 -33.65  115.33
# 7      Hermanus           1      ZA  1580788957        94 -34.42   19.23
# ..          ...         ...     ...         ...       ...    ...     ...
# 535  Crib Point           0      AU  1580789050        59 -38.35  145.20
# 537      Touros          40      BR  1580789050        88  -5.20  -35.46
# 539     Pitanga           0      BR  1580788839        95 -24.76  -51.76
# 540      Acarau          36      BR  1580789050        93  -2.89  -40.12
# 548  Walvis Bay          33      NA  1580789052        93 -22.96   14.51
#
#      Temperature  Max Temp  Wind Speed
# 0          78.84     78.84       11.99
# 1          51.80     51.80       16.11
# 3          73.90     75.00        5.82
# 4          86.59     90.00        9.42
# 7          70.36     75.00       16.26
# ..           ...       ...         ...
# 535        66.92     69.01       11.79
# 537        78.80     78.80        4.70
# 539        63.90     63.90        7.72
# 540        75.54     75.54        2.89
# 548        63.00     63.00        5.99
#
# [169 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = north["Lat"]
max_temp = north["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, max_temp)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, max_temp, color="blue")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(3,-20),fontsize=15,color="red")
plt.title("Northern Hemisphere vs Max Temp" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid(True)
plt.ylim([-50, 100])
plt.xlim([-5, 90])
print(f"The r-squared is: {rvalue}")

#plt.savefig("north_max_temp.png")
plt.show()
# Out:
# The r-squared is: -0.8664111244475423

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = south["Lat"]
max_temp = south["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, max_temp)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, max_temp, color="blue")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(-30,40),fontsize=15,color="red")
plt.title("Southern Hemisphere vs Max Temp" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid(True)
plt.ylim([30, 115])
plt.xlim([-60, 5])
print(f"The r-squared is: {rvalue}")

#plt.savefig("south_max_temp.png")
plt.show()
# Out:
# The r-squared is: 0.5250157318239093

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = north["Lat"]
humidity = north["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, humidity, color="orange")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(45,20),fontsize=15,color="red")
plt.title("Northern Hemisphere vs Humidity" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)
plt.ylim([0, 110])
plt.xlim([-5, 85])
print(f"The r-squared is: {rvalue}")

#plt.savefig("north_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.37748253099725476

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = south["Lat"]
humidity = south["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, humidity, color="orange")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(-28,20),fontsize=15,color="red")
plt.title("Southern Hemisphere vs Humidity" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)
plt.ylim([0, 110])
plt.xlim([-60, 5])
print(f"The r-squared is: {rvalue}")

#plt.savefig("south_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.1526480506691333

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = north["Lat"]
cloudiness = north["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, cloudiness, color="black")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(46,10),fontsize=15,color="red")
plt.title("Northern Hemisphere vs Cloudiness" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)
plt.ylim([-10, 112])
plt.xlim([-6, 85])
print(f"The r-squared is: {rvalue}")

#plt.savefig("north_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.29939058809215063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = south["Lat"]
cloudiness = south["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, cloudiness, color="black")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(-22,5),fontsize=15,color="red")
plt.title("Southern Hemisphere vs Cloudiness" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)
plt.ylim([-10, 112])
plt.xlim([-60, 5])
print(f"The r-squared is: {rvalue}")

#plt.savefig("south_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.29125538467429357

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = north["Lat"]
wind_speed = north["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, wind_speed, color="purple")
plt.plot(latitude, regress_values,"r-")

plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.title("Northern Hemisphere vs Wind Speed" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.ylim([-5, 35])
plt.xlim([-5, 85])
print(f"The r-squared is: {rvalue}")

#plt.savefig("north_wind_speed.png")
plt.show()
# Out:
# The r-squared is: 0.23511816056190502

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = south["Lat"]
wind_speed = south["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, wind_speed, color="purple")

plt.annotate(line_eq,(-27,30),fontsize=15,color="red")
plt.plot(latitude, regress_values,"r-")
plt.title("Southern Hemisphere vs Wind Speed" + " " + "(" + datetime.now().strftime('%m/%d/%Y') + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.ylim([-3, 35])
plt.xlim([-60, 5])
print(f"The r-squared is: {rvalue}")

#plt.savefig("south_wind_speed.png")
plt.show()
# Out:
# The r-squared is: -0.3386148405953168
